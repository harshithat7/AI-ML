# %%
P_heads = 1/2
P_six = 1/6
P_heads_and_six = P_heads * P_six
print("Independent Events:")
print("P(Heads AND 6) =", P_heads_and_six)
print("Decimal:", float(P_heads_and_six))
P_red_first = 5/10
P_red_second_given_first = 4/9 
P_both_red = P_red_first * P_red_second_given_first
print("\nDependent Events:")
print("P(Both Red) =", P_both_red)
print("Decimal:", float(P_both_red))
# Out:
# Independent Events:
# P(Heads AND 6) = 0.08333333333333333
# Decimal: 0.08333333333333333
#
# Dependent Events:
# P(Both Red) = 0.2222222222222222
# Decimal: 0.2222222222222222
