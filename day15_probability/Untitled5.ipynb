# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv(r"C:\Users\user\Downloads\car_price_prediction.csv")

# %%
data
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
data.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
data.shape
# Out:
# (19237, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
data.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
plt.figure(figsize=(8,4))
sns.histplot(data["Prod. year"])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data)
plt.show()

# %%
plt.figure()
sns.pairplot(data)

# %%
plt.figure(figsize=(6,4))
sns.histplot(data)
plt.show()

# %%
data['ID'].skew()
# Out:
# np.float64(-11.868234798415783)

# %%
data.hist(figsize=(10,8))
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = data[["ID", "Price", "Prod. year", "Cylinders", "Airbags"]]
y = data["Price"]

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
polynomial = PolynomialFeatures(degree=2)
poly_features = polynomial.fit_transform(x_train)
model = LinearRegression()
model.fit(poly_features, y_train)
# Out:
# LinearRegression()

# %%
model.coef_, model.intercept_
# Out:
# (array([ 0.00000000e+00,  3.53794388e-04,  1.07540106e-06,  2.07803411e-07,
#         -7.54331657e-10,  2.54729754e-08, -1.61411783e-13, -5.60526132e-11,
#         -1.70151124e-07,  1.94456509e-07, -6.35585860e-09,  3.13350616e-10,
#          4.97838220e-04, -2.14521927e-04,  2.46917913e-05,  8.08217531e-04,
#         -1.78233979e-08,  5.04174835e-05, -1.67987789e-08,  2.04529304e-07,
#          1.16018581e-07]),
#  np.float64(-3478.697554765662))

# %%
fig, axs = plt.subplots(1,5, figsize = (16,6))
axs[0].boxplot(data["ID"])
axs[1].boxplot(data["Price"])
axs[2].boxplot(data["Prod. year"])
axs[3].boxplot(data["Cylinders"])
axs[4].boxplot(data["Airbags"])
plt.show()

# %%
data.dtypes
# Out:
# ID                    int64
# Price                 int64
# Levy                 object
# Manufacturer         object
# Model                object
# Prod. year            int64
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object

# %%
Q1 = data.select_dtypes(include='number').quantile(0.25)
Q3 = data.select_dtypes(include='number').quantile(0.75)
IQR = Q3 - Q1

# %%
IQR
# Out:
# ID            103662.0
# Price          16744.0
# Prod. year         6.0
# Cylinders          0.0
# Airbags            8.0
# dtype: float64

# %%
upper_limit = Q3 + 1.5*IQR
lower_limit = Q1 - 1.5*IQR

# %%
upper_limit, lower_limit
# Out:
# (ID            45957529.0
#  Price            47191.0
#  Prod. year        2024.0
#  Cylinders            4.0
#  Airbags             24.0
#  dtype: float64,
#  ID            45542881.0
#  Price           -19785.0
#  Prod. year        2000.0
#  Cylinders            4.0
#  Airbags             -8.0
#  dtype: float64)

# %%
data.drop_duplicates()
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
data.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
numeric_data = data.select_dtypes(include='number')

# %%
outliers = ((numeric_data < lower_limit) | 
            (numeric_data > upper_limit)).any(axis=1)

# %%
outliners = ((numeric_data < lower_limit) | (numeric_data > upper_limit)).any(axis=1)
outlier_data = data[outliners]
cleaned_data = data[~outliners]

# %%
outlier_data
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 9      45756839  26657     -          LEXUS   RX 350        2007       Jeep
# 10     45621750    941  1053  MERCEDES-BENZ    E 350        2014      Sedan
# 11     45814819   8781     -           FORD  Transit        1999   Microbus
# ...         ...    ...   ...            ...      ...         ...        ...
# 19227  45769427  29793  1053  MERCEDES-BENZ    E 350        2014      Sedan
# 19228  45773726    706  1850  MERCEDES-BENZ    E 350        2008      Sedan
# 19229  39977395     50     -         TOYOTA    Prius        2008  Hatchback
# 19231  45772306   5802  1055  MERCEDES-BENZ    E 350        2013      Sedan
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
#
# ...

# %%
cleaned_data
# Out:
#              ID  Price  Levy Manufacturer     Model  Prod. year   Category  \
# 2      45774419   8467     -        HONDA       FIT        2006  Hatchback
# 3      45769185   3607   862         FORD    Escape        2011       Jeep
# 4      45809263  11726   446        HONDA       FIT        2014  Hatchback
# 5      45802912  39493   891      HYUNDAI  Santa FE        2016       Jeep
# 6      45656768   1803   761       TOYOTA     Prius        2010  Hatchback
# ...         ...    ...   ...          ...       ...         ...        ...
# 19230  45760891    470   645       TOYOTA     Prius        2011  Hatchback
# 19233  45778856  15681   831      HYUNDAI    Sonata        2011      Sedan
# 19234  45804997  26108   836      HYUNDAI    Tucson        2010       Jeep
# 19235  45793526   5331  1288    CHEVROLET   Captiva        2007       Jeep
# 19236  45813273    470   753      HYUNDAI    Sonata        2012      Sedan
#
# ...
