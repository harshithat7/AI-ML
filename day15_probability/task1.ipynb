# %%
import random 
rolls = [random.randint(1,6) + random.randint(1,6) for _ in range(1000)]
sum_7_count = rolls.count(7)
prob_7 = sum_7_count / 1000
print("Experimental Probability(sum=7):", prob_7)
# Out:
# Experimental Probability(sum=7): 0.181
