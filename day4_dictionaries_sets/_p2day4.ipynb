# %%
a = {1,2,3,4,5,6,7,10}

# %%
a
# Out:
# {2, 3, 4, 6, 7, 10}

# %%
a.discard(5)

# %%
a
# Out:
# {1, 2, 3, 4, 6, 7, 10}

# %%
a.pop()
# Out:
# 1

# %%
b = {1,2,3,4,5,7,8,10}

# %%
b
# Out:
# {1, 2, 3, 4, 5, 7, 8, 10}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 10}

# %%
a.intersection(b)
# Out:
# {2, 3, 4, 7, 10}

# %%
a.difference(b)
# Out:
# {6}
