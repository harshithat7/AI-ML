# %%
dict_ = {"id": 1, "name": "ABC", "age": 21}

# %%
dict_.get("id")
# Out:
# 1

# %%
dict_.get("name")
# Out:
# 'ABC'

# %%
dict_["id"]=2

# %%
dict_.update({"place":"banglore"})

# %%
dict_
# Out:
# {'id': 2, 'name': 'ABC', 'age': 21, 'place': 'banglore'}

# %%
list(dict_.keys()),list(dict_.values())
# Out:
# (['id', 'name', 'age', 'place'], [2, 'ABC', 21, 'banglore'])

# %%
dict_.pop("id")
# Out:
# 2

# %%
dict_
# Out:
# {'name': 'ABC', 'age': 21, 'place': 'banglore'}

# %%
dict_.popitem()
# Out:
# ('place', 'banglore')

# %%
dict_
# Out:
# {'name': 'ABC', 'age': 21}
