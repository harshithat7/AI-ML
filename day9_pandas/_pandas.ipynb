# %%
import pandas as pd
import numpy as np

# %%
data = pd.Series([1,2,3,4,5], index = ["a","b","c","d","e"])

# %%
data
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data.name = "Numbers"

# %%
data.size
# Out:
# 5

# %%
data.shape
# Out:
# (5,)

# %%
data
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: Numbers, dtype: int64

# %%
data.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
data.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
data.loc["a"],data.iloc[3]
# Out:
# (np.int64(1), np.int64(4))

# %%
data.loc["a"::2],data.iloc[3]
# Out:
# (a    1
#  c    3
#  e    5
#  Name: Numbers, dtype: int64,
#  np.int64(4))

# %%
data.loc[["a","c","e"]],data.iloc[3]
# Out:
# (a    1
#  c    3
#  e    5
#  Name: Numbers, dtype: int64,
#  np.int64(4))

# %%
dictionary = {
    "USN":[1,2,3],
    "Name":["ABC","DEF","PQR"],
    "Age":[21,20,21],
    "Branch":["CS","AI","DS"]
}

# %%
df = pd.DataFrame(dictionary)
df
# Out:
#    USN Name  Age Branch
# 0    1  ABC   21     CS
# 1    2  DEF   20     AI
# 2    3  PQR   21     DS

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\sample.csv")

# %%
data
# Out:
#     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0            0    101    Ram         IT   25   50000           2  2021-01-15
# 1            1    102  Shyam         HR   30   45000           5  2019-03-10
# 2            2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3            3    104  Anita         IT   35   75000          10  2015-09-30
# 4            4    105  Kiran         HR   32   52000           7  2018-06-12
# 5            5    106   John    Finance   29   58000           3  2021-11-05
# 6            6    107  Meena         IT   41   82000          15  2010-04-18
# 7            7    108  David         HR   26   48000           2  2022-02-14
# 8            8    109   Sara    Finance   38   61000          12  2013-12-01
# 9            9    110  Arjun         IT   27   54000           4  2020-08-19
# 10          10    111   Ravi         HR   33   47000           6  2017-05-23
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0           0    101    Ram         IT   25   50000           2  2021-01-15
# 1           1    102  Shyam         HR   30   45000           5  2019-03-10
# 2           2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3           3    104  Anita         IT   35   75000          10  2015-09-30
# 4           4    105  Kiran         HR   32   52000           7  2018-06-12
#
#         City  PerformanceScore
# 0  Bangalore               4.5
# 1     Mumbai               3.8
# 2      Delhi               4.2
# 3  Bangalore               4.9
# 4     Mumbai               4.1

# %%
data.describe()
# Out:
#        Unnamed: 0      EmpID        Age        Salary  Experience  \
# count    20.00000   20.00000  20.000000     20.000000   20.000000
# mean      9.50000  110.50000  32.700000  59875.000000    7.400000
# std       5.91608    5.91608   5.449288  13388.796377    4.615762
# min       0.00000  101.00000  25.000000  45000.000000    2.000000
# 25%       4.75000  105.75000  28.750000  50750.000000    4.000000
# 50%       9.50000  110.50000  31.500000  56500.000000    6.000000
# 75%      14.25000  115.25000  36.250000  61250.000000   10.250000
# max      19.00000  120.00000  45.000000  90000.000000   18.000000
#
#        PerformanceScore
# count         20.000000
# mean           4.190000
# std            0.415363
# min            3.500000
# 25%            3.900000
# 50%            4.150000
# 75%            4.425000
# max            4.900000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20 non-null     int64
#  1   EmpID             20 non-null     int64
#  2   Name              20 non-null     object
#  3   Department        20 non-null     object
#  4   Age               20 non-null     int64
#  5   Salary            20 non-null     int64
#  6   Experience        20 non-null     int64
#  7   JoiningDate       20 non-null     object
#  8   City              20 non-null     object
#  9   PerformanceScore  20 non-null     float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.7+ KB

# %%
data.shape
# Out:
# (20, 10)

# %%
data.sample()
# Out:
#     Unnamed: 0  EmpID  Name Department  Age  Salary  Experience JoiningDate  \
# 10          10    111  Ravi         HR   33   47000           6  2017-05-23
#
#       City  PerformanceScore
# 10  Mumbai               3.6

# %%
data[["Name","Department","Salary"]]
# Out:
#      Name Department  Salary
# 0     Ram         IT   50000
# 1   Shyam         HR   45000
# 2   Geeta    Finance   60000
# 3   Anita         IT   75000
# 4   Kiran         HR   52000
# 5    John    Finance   58000
# 6   Meena         IT   82000
# 7   David         HR   48000
# 8    Sara    Finance   61000
# 9   Arjun         IT   54000
# 10   Ravi         HR   47000
# 11  Priya    Finance   59000
# 12  Kunal         IT   90000
# 13  Sneha         HR   51000
# 14  Vijay    Finance   62000
# 15   Neha         IT   88000
# 16   Amit         HR   53000
# 17  Pooja    Finance   57000
# 18  Rahul         IT   56000
# 19  Divya         HR   49500

# %%
data[["Name","Department","Salary"]].head(2)
# Out:
#     Name Department  Salary
# 0    Ram         IT   50000
# 1  Shyam         HR   45000

# %%
type(data.Name)
# Out:
# pandas.core.series.Series

# %%
datas = pd.read_csv(r"C:\Users\user\Downloads\test2.csv")

# %%
datas
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
datas.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          0
# Age           1
# Department    0
# Salary        1
# dtype: int64

# %%
datas.isnull()
# Out:
#    Unnamed: 0   Name    Age  Department  Salary
# 0       False  False  False       False   False
# 1       False  False  False       False   False
# 2       False  False  False       False   False
# 3       False  False   True       False   False
# 4       False  False  False       False    True
# 5       False  False  False       False   False

# %%
datas[["Name","Age","Salary"]]
# Out:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob  30.0  60000.0
# 2  Charlie  35.0  70000.0
# 3    David   NaN  62000.0
# 4      Eve  29.0      NaN
# 5    Alice  25.0  50000.0

# %%
datas.loc["0":"1","Name":"Department"]
# Out:
#     Name   Age Department
# 0  Alice  25.0         HR
# 1    Bob  30.0         IT

# %%
 datas.loc["1":"3","Name":"Salary"]
# Out:
#       Name   Age Department   Salary
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0

# %%
datas.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
datas.rename(columns={"Name":"N","Age":"A","Department":"D","Salary":"S"},inplace=True)

# %%
datas
# Out:
#    Unnamed: 0        N     A        D        S
# 0           0    Alice  25.0       HR  50000.0
# 1           1      Bob  30.0       IT  60000.0
# 2           2  Charlie  35.0  Finance  70000.0
# 3           3    David   NaN       IT  62000.0
# 4           4      Eve  29.0       HR      NaN
# 5           5    Alice  25.0       HR  50000.0

# %%
datas.drop('Unnamed: 0', axis=1, inplace=True)

# %%
datas
# Out:
#          N     A        D        S
# 0    Alice  25.0       HR  50000.0
# 1      Bob  30.0       IT  60000.0
# 2  Charlie  35.0  Finance  70000.0
# 3    David   NaN       IT  62000.0
# 4      Eve  29.0       HR      NaN
# 5    Alice  25.0       HR  50000.0

# %%
datas["Updated_salary"]=datas["S"]+5000

# %%
datas
# Out:
#          N     A        D        S  Updated_salary
# 0    Alice  25.0       HR  50000.0         55000.0
# 1      Bob  30.0       IT  60000.0         65000.0
# 2  Charlie  35.0  Finance  70000.0         75000.0
# 3    David   NaN       IT  62000.0         67000.0
# 4      Eve  29.0       HR      NaN             NaN
# 5    Alice  25.0       HR  50000.0         55000.0

# %%
datas[datas["A"]>25]
# Out:
#          N     A        D        S  Updated_salary
# 1      Bob  30.0       IT  60000.0         65000.0
# 2  Charlie  35.0  Finance  70000.0         75000.0
# 4      Eve  29.0       HR      NaN             NaN

# %%
datas.rename(columns={"N":"Name","A":"Age","D":"Department","S":"Salary"},inplace=True)

# %%
datas
# Out:
#       Name   Age Department   Salary  Updated_salary
# 0    Alice  25.0         HR  50000.0         55000.0
# 1      Bob  30.0         IT  60000.0         65000.0
# 2  Charlie  35.0    Finance  70000.0         75000.0
# 3    David   NaN         IT  62000.0         67000.0
# 4      Eve  29.0         HR      NaN             NaN
# 5    Alice  25.0         HR  50000.0         55000.0

# %%
datas["Updated_salary2"]=datas["Updated_salary"]+5000

# %%
datas
# Out:
#       Name   Age Department   Salary  Updated_salary  Updated_salary2
# 0    Alice  25.0         HR  50000.0         55000.0          60000.0
# 1      Bob  30.0         IT  60000.0         65000.0          70000.0
# 2  Charlie  35.0    Finance  70000.0         75000.0          80000.0
# 3    David   NaN         IT  62000.0         67000.0          72000.0
# 4      Eve  29.0         HR      NaN             NaN              NaN
# 5    Alice  25.0         HR  50000.0         55000.0          60000.0

# %%
datas
# Out:
#       Name   Age Department   Salary  Updated_salary  Updated_salary2
# 0    Alice  25.0         HR  50000.0         55000.0          60000.0
# 1      Bob  30.0         IT  60000.0         65000.0          70000.0
# 2  Charlie  35.0    Finance  70000.0         75000.0          80000.0
# 3    David   NaN         IT  62000.0         67000.0          72000.0
# 4      Eve  29.0         HR      NaN             NaN              NaN
# 5    Alice  25.0         HR  50000.0         55000.0          60000.0

# %%
datas.isnull().sum()
# Out:
# Name               0
# Age                1
# Department         0
# Salary             1
# Updated_salary     1
# Updated_salary2    1
# dtype: int64

# %%
datas["Age"].fillna(value=0)
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3     0.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
datas["Age"] = datas["Age"].fillna(value=datas["Age"].mean())
datas["Salary"] = datas["Salary"].fillna(value=datas["Salary"].mean())

# %%
datas
# Out:
#       Name   Age Department   Salary  Updated_salary  Updated_salary2
# 0    Alice  25.0         HR  50000.0         55000.0          60000.0
# 1      Bob  30.0         IT  60000.0         65000.0          70000.0
# 2  Charlie  35.0    Finance  70000.0         75000.0          80000.0
# 3    David  28.8         IT  62000.0         67000.0          72000.0
# 4      Eve  29.0         HR  58400.0             NaN              NaN
# 5    Alice  25.0         HR  50000.0         55000.0          60000.0

# %%
datas["Department"].value_counts()
# Out:
# Department
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
datas["Salary"].value_counts()
# Out:
# Salary
# 50000.0    2
# 60000.0    1
# 70000.0    1
# 62000.0    1
# 58400.0    1
# Name: count, dtype: int64

# %%
datas["Age"] = datas["Age"].fillna(method="ffill")
datas["Age"] = datas["Age"].fillna(method="bfill")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7540\3396199081.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   datas["Age"] = datas["Age"].fillna(method="ffill")
# C:\Users\user\AppData\Local\Temp\ipykernel_7540\3396199081.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   datas["Age"] = datas["Age"].fillna(method="bfill")

# %%
datas
# Out:
#       Name   Age Department   Salary  Updated_salary  Updated_salary2
# 0    Alice  25.0         HR  50000.0         55000.0          60000.0
# 1      Bob  30.0         IT  60000.0         65000.0          70000.0
# 2  Charlie  35.0    Finance  70000.0         75000.0          80000.0
# 3    David  28.8         IT  62000.0         67000.0          72000.0
# 4      Eve  29.0         HR  58400.0             NaN              NaN
# 5    Alice  25.0         HR  50000.0         55000.0          60000.0

# %%
datas.Age.ffill()
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
datas.Age.bfill()
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
datas["Updated_salary"] = datas["Salary"].apply(lambda x:x+500)

# %%
datas
# Out:
#       Name   Age Department   Salary  Updated_salary  Updated_salary2
# 0    Alice  25.0         HR  50000.0         50500.0          60000.0
# 1      Bob  30.0         IT  60000.0         60500.0          70000.0
# 2  Charlie  35.0    Finance  70000.0         70500.0          80000.0
# 3    David  28.8         IT  62000.0         62500.0          72000.0
# 4      Eve  29.0         HR  58400.0         58900.0              NaN
# 5    Alice  25.0         HR  50000.0         50500.0          60000.0

# %%
datas["Level"] = datas.apply(lambda row: "High" if row["Salary"]>60000 else "Low", axis=1)

# %%
datas
# Out:
#       Name   Age Department   Salary  Updated_salary  Updated_salary2 Level
# 0    Alice  25.0         HR  50000.0         50500.0          60000.0   Low
# 1      Bob  30.0         IT  60000.0         60500.0          70000.0   Low
# 2  Charlie  35.0    Finance  70000.0         70500.0          80000.0  High
# 3    David  28.8         IT  62000.0         62500.0          72000.0  High
# 4      Eve  29.0         HR  58400.0         58900.0              NaN   Low
# 5    Alice  25.0         HR  50000.0         50500.0          60000.0   Low

# %%
datas.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    70000.0
# HR         52800.0
# IT         61000.0
# Name: Salary, dtype: float64

# %%
filtered = datas[(datas["Age"]>28) & (datas["Salary"]>50000)]

# %%
filtered
# Out:
#       Name   Age Department   Salary  Updated_salary  Updated_salary2 Level
# 1      Bob  30.0         IT  60000.0         60500.0          70000.0   Low
# 2  Charlie  35.0    Finance  70000.0         70500.0          80000.0  High
# 3    David  28.8         IT  62000.0         62500.0          72000.0  High
# 4      Eve  29.0         HR  58400.0         58900.0              NaN   Low

# %%
filtered = datas[(datas["Age"]>28) & (datas["Department"] == "IT")]

# %%
filtered
# Out:
#     Name   Age Department   Salary  Updated_salary  Updated_salary2 Level
# 1    Bob  30.0         IT  60000.0         60500.0          70000.0   Low
# 3  David  28.8         IT  62000.0         62500.0          72000.0  High
