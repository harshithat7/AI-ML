# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {'Price': [200,300,400,500,600,700,800,1000,1200],
        'City': ['NYC', 'LA', 'NYC', 'Chicago', 'LA', 'NYC', 'Chicago', 'LA', 'NYC']}
df = pd.DataFrame(data)
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.histplot(df['Price'], kde=True)
plt.title('Price Distribution')
print("Skewness:", df['Price'].skew())
print("Kurtosis:", df['Price'].kurtosis())
plt.subplot(1,2,2)
sns.countplot(x='City', data=df)
plt.title('City Frequency')
plt.tight_layout()
plt.show()
# Out:
# Skewness: 0.4681351461372976
# Kurtosis: -0.5646295294753925
